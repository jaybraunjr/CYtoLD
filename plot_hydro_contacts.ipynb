# %%
import MDAnalysis as mda 
import numpy as np
import pandas as pd
from MDAnalysis.analysis import distances
from MDAnalysis.analysis import contacts
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

# %%
import pandas as pd
import os

# The list of folders
folders = ['rep1', 'rep2', 'rep3', 'rep4', 'rep5', 'rep6', 'rep7', 'rep8']

# The new header names
new_headers = ['Frame', '228(leu) PL acyl', '232(val) PL acyl', '236(leu) PL acyl', '239(leu) PL acyl', '243(leu) PL acyl', '228(leu) TG acyl', '232(val) TG acyl', '236(leu) TG acyl', '239(leu) TG acyl', '243(leu) TG acyl']

# Loop through all the folders
for folder in folders:
    file_path = f"{folder}/tot.csv"
    # Read the file
    df = pd.read_csv(file_path)
    df.drop(columns=df.columns[0], axis=1,  inplace=True)
    print(df)
    # Update the headers
    df.columns = new_headers
    # Save the modified file back to disk
    df.to_csv(file_path, index=False)
# Out:
#       228(leu) PL acyl  232(val) PL acyl  236(leu) PL acyl  239(leu) PL acyl  \
# 0                  NaN               NaN               NaN               NaN
# 1                  NaN               NaN               NaN               NaN
# 2                  NaN               NaN               NaN               NaN
# 3                  NaN               NaN               NaN               NaN
# 4                  NaN               NaN               NaN               NaN
# ...                ...               ...               ...               ...
# 996          41.600000         29.800000         24.066667         21.533333
# 997          41.666667         30.600000         23.866667         22.733333
# 998          42.200000         30.533333         24.400000         21.933333
# 999          42.866667         29.333333         22.666667         21.600000
# 1000         41.733333         29.466667         22.933333         22.066667
#
# ...

# %%
rol = pd.read_csv('rep1/tot.csv')

# %%
fig, axs = plt.subplots(4, 2, figsize=(8, 11))
axs = axs.ravel()

for i, trajnum in enumerate(range(1, 9)):
    rol = pd.read_csv(f'rep{trajnum}/tot.csv')
    
    rol.plot(x='Frame',y='228(leu) PL acyl', color='red',ax=axs[i], legend=False)
    rol.plot(x='Frame',y='232(val) PL acyl', color='maroon',ax=axs[i])
    rol.plot(x='Frame',y='236(leu) PL acyl', color='tomato',ax=axs[i])
    rol.plot(x='Frame',y='239(leu) PL acyl', color='sienna',ax=axs[i])
    rol.plot(x='Frame',y='243(leu) PL acyl', color='salmon',ax=axs[i])

    rol.plot(x='Frame',y='228(leu) TG acyl', color='navy',ax=axs[i])
    rol.plot(x='Frame',y='232(val) TG acyl', color='royalblue',ax=axs[i])
    rol.plot(x='Frame',y='236(leu) TG acyl', color='lightsteelblue',ax=axs[i])
    rol.plot(x='Frame',y='239(leu) TG acyl', color='slategrey',ax=axs[i])
    rol.plot(x='Frame',y='243(leu) TG acyl', color='dodgerblue',ax=axs[i])

    axs[i].set_title(f'hydrophobic contacts rep-{trajnum} pure-TG')

plt.tight_layout()
plt.show()

# %%
fig, axs = plt.subplots(4, 2, figsize=(8, 11))
axs = axs.ravel()

red_patch = mpatches.Patch(color='red', label='228(leu) PL acyl')
maroon_patch = mpatches.Patch(color='maroon', label='232(val) PL acyl')
tomato_patch = mpatches.Patch(color='tomato', label='236(leu) PL acyl')
sienna_patch = mpatches.Patch(color='sienna', label='239(leu) PL acyl')
salmon_patch = mpatches.Patch(color='salmon', label='243(leu) PL acyl')

navy_patch = mpatches.Patch(color='navy', label='228(leu) TG acyl')
royalblue_patch = mpatches.Patch(color='royalblue', label='232(val) TG acyl')
lightsteelblue_patch = mpatches.Patch(color='lightsteelblue', label='236(leu) TG acyl')
slategrey_patch = mpatches.Patch(color='slategrey', label='239(leu) TG acyl')
dodgerblue_patch = mpatches.Patch(color='dodgerblue', label='243(leu) TG acyl')

legend_handles = [red_patch, maroon_patch, tomato_patch, sienna_patch, salmon_patch, navy_patch, royalblue_patch, lightsteelblue_patch, slategrey_patch, dodgerblue_patch]

for i, trajnum in enumerate(range(1, 9)):
    rol = pd.read_csv(f'rep{trajnum}/tot.csv')
    rol.plot(x='Frame',y='228(leu) PL acyl', color='red',ax=axs[i], legend=None)
    rol.plot(x='Frame',y='232(val) PL acyl', color='maroon',ax=axs[i])
    rol.plot(x='Frame',y='236(leu) PL acyl', color='tomato',ax=axs[i])
    rol.plot(x='Frame',y='239(leu) PL acyl', color='sienna',ax=axs[i])
    rol.plot(x='Frame',y='243(leu) PL acyl', color='salmon',ax=axs[i])

    rol.plot(x='Frame',y='228(leu) TG acyl', color='navy',ax=axs[i])
    rol.plot(x='Frame',y='232(val) TG acyl', color='royalblue',ax=axs[i])
    rol.plot(x='Frame',y='236(leu) TG acyl', color='lightsteelblue',ax=axs[i])
    rol.plot(x='Frame',y='239(leu) TG acyl', color='slategrey',ax=axs[i])
#     rol.plot(x='Frame',y='243(leu) TG

# %%
fig, axs = plt.subplots(4, 2, figsize=(8, 11))
axs = axs.ravel()

for i, trajnum in enumerate(range(1, 9)):
    rol = pd.read_csv(f'rep{trajnum}/tot.csv')
    
    rol.plot(x='Frame',y='228(leu) PL acyl', color='red',ax=axs[i], legend=False)
    rol.plot(x='Frame',y='232(val) PL acyl', color='maroon',ax=axs[i], legend=False)
    rol.plot(x='Frame',y='236(leu) PL acyl', color='tomato',ax=axs[i], legend=False)
    rol.plot(x='Frame',y='239(leu) PL acyl', color='sienna',ax=axs[i], legend=False)
    rol.plot(x='Frame',y='243(leu) PL acyl', color='salmon',ax=axs[i], legend=False)

    rol.plot(x='Frame',y='228(leu) TG acyl', color='navy',ax=axs[i], legend=False)
    rol.plot(x='Frame',y='232(val) TG acyl', color='royalblue',ax=axs[i], legend=False)
    rol.plot(x='Frame',y='236(leu) TG acyl', color='lightsteelblue',ax=axs[i], legend=False)
    rol.plot(x='Frame',y='239(leu) TG acyl', color='slategrey',ax=axs[i], legend=False)
    rol.plot(x='Frame',y='243(leu) TG acyl', color='dodgerblue',ax=axs[i], legend=False)

    axs[i].set_title(f'hydrophobic contacts rep-{trajnum} pure-TG')

    


plt.tight_layout()
plt.show()

# %%
fig, axs = plt.subplots(4, 2, figsize=(8, 11))
axs = axs.ravel()

for i, trajnum in enumerate(range(1, 9)):
    rol = pd.read_csv(f'rep{trajnum}/tot.csv')
    rol.plot(x='Frame',y='228(leu) PL acyl', color='red',ax=axs[i],legend=False)
    rol.plot(x='Frame',y='232(val) PL acyl', color='maroon',ax=axs[i],legend=True)
    rol.plot(x='Frame',y='236(leu) PL acyl', color='tomato',ax=axs[i],legend=False)
    rol.plot(x='Frame',y='239(leu) PL acyl', color='sienna',ax=axs[i],legend=False)
    rol.plot(x='Frame',y='243(leu) PL acyl', color='salmon',ax=axs[i],legend=False)

    rol.plot(x='Frame',y='228(leu) TG acyl', color='navy',ax=axs[i],legend=False)
    rol.plot(x='Frame',y='232(val) TG acyl', color='royalblue',ax=axs[i],legend=False)
    rol.plot(x='Frame',y='236(leu) TG acyl', color='lightsteelblue',ax=axs[i],legend=False)
    rol.plot(x='Frame',y='239(leu) TG acyl', color='slategrey',ax=axs[i],legend=False)
    rol.plot(x='Frame',y='243(leu) TG acyl', color='dodgerblue',ax=axs[i],legend=False)

    axs[i].set_title(f'hydrophobic contacts rep-{trajnum} pure-TG')

    if i > 5:
        axs[i].set_xlabel('Frame')

fig.tight_layout()

# %%
fig, axs = plt.subplots(4, 2, figsize=(8, 11))
axs = axs.ravel()

for i, trajnum in enumerate(range(1, 9)):
    rol = pd.read_csv(f'rep{trajnum}/tot.csv')
    rol.plot(x='Frame',y='228(leu) PL acyl', color='red',ax=axs[i], legend=None)
    rol.plot(x='Frame',y='232(val) PL acyl', color='maroon',ax=axs[i],legend= None)
    rol.plot(x='Frame',y='236(leu) PL acyl', color='tomato',ax=axs[i],legend=None)
    rol.plot(x='Frame',y='239(leu) PL acyl', color='sienna',ax=axs[i],legend=None)
    rol.plot(x='Frame',y='243(leu) PL acyl', color='salmon',ax=axs[i],legend=None)

    rol.plot(x='Frame',y='228(leu) TG acyl', color='navy',ax=axs[i],legend=None)
    rol.plot(x='Frame',y='232(val) TG acyl', color='royalblue',ax=axs[i],legend=None)
    rol.plot(x='Frame',y='236(leu) TG acyl', color='lightsteelblue',ax=axs[i],legend=None)
    rol.plot(x='Frame',y='239(leu) TG acyl', color='slategrey',ax=axs[i],legend=None)
    rol.plot(x='Frame',y='243(leu) TG acyl', color='dodgerblue',ax=axs[i],legend=None)

    axs[i].set_title(f'hydrophobic contacts rep-{trajnum} pure-TG')
    if i not in [6,7]:
        axs[i].set_xlabel("")
        axs[i].set_xticks([])

# %%
fig, axs = plt.subplots(4, 2, figsize=(8, 11))
axs = axs.ravel()

for i, trajnum in enumerate(range(1, 9)):
    rol = pd.read_csv(f'rep{trajnum}/tot.csv')
    
    rol.plot(x='Frame',y='228(leu) PL acyl', color='red',ax=axs[i],label='228(leu) PL acyl')
    rol.plot(x='Frame',y='232(val) PL acyl', color='maroon',ax=axs[i],label='232(val) PL acyl')
    rol.plot(x='Frame',y='236(leu) PL acyl', color='tomato',ax=axs[i],label='236(leu) PL acyl')
    rol.plot(x='Frame',y='239(leu) PL acyl', color='sienna',ax=axs[i],label='239(leu) PL acyl')
    rol.plot(x='Frame',y='243(leu) PL acyl', color='salmon',ax=axs[i],label='243(leu) PL acyl')

    rol.plot(x='Frame',y='228(leu) TG acyl', color='navy',ax=axs[i],label='228(leu) TG acyl')
    rol.plot(x='Frame',y='232(val) TG acyl', color='royalblue',ax=axs[i],label='232(val) TG acyl')
    rol.plot(x='Frame',y='236(leu) TG acyl', color='lightsteelblue',ax=axs[i],label='236(leu) TG acyl')
    rol.plot(x='Frame',y='239(leu) TG acyl', color='slategrey',ax=axs[i],label='239(leu) TG acyl')
    rol.plot(x='Frame',y='243(leu) TG acyl', color='dodgerblue',ax=axs[i],label='243(leu) TG acyl')

    axs[i].set_title(f'hydrophobic contacts rep-{trajnum} pure-TG')

handles, labels = axs[0].get_legend_handles_labels()
fig.legend(handles, labels, loc='upper center',ncol=5, bbox_to_anchor=(0.5, 0.93))

plt.tight_layout()
plt.show()

# %%
fig, axs = plt.subplots(4, 2, figsize=(8, 11))
axs = axs.ravel()

for i, trajnum in enumerate(range(1, 9)):
    rol = pd.read_csv(f'rep{trajnum}/tot.csv')
    
    rol.plot(x='Frame',y='228(leu) PL acyl', color='red',ax=axs[i])
    rol.plot(x='Frame',y='232(val) PL acyl', color='maroon',ax=axs[i])
    rol.plot(x='Frame',y='236(leu) PL acyl', color='tomato',ax=axs[i])
    rol.plot(x='Frame',y='239(leu) PL acyl', color='sienna',ax=axs[i])
    rol.plot(x='Frame',y='243(leu) PL acyl', color='salmon',ax=axs[i])

    rol.plot(x='Frame',y='228(leu) TG acyl', color='navy',ax=axs[i])
    rol.plot(x='Frame',y='232(val) TG acyl', color='royalblue',ax=axs[i])
    rol.plot(x='Frame',y='236(leu) TG acyl', color='lightsteelblue',ax=axs[i])
    rol.plot(x='Frame',y='239(leu) TG acyl', color='slategrey',ax=axs[i])
    rol.plot(x='Frame',y='243(leu) TG acyl', color='dodgerblue',ax=axs[i])

    axs[i].set_title(f'hydrophobic contacts rep-{trajnum} pure-TG')
    axs[i].legend_.remove()

legend_elements = [mpatches.Patch(color='red', label='228(leu) PL acyl'),
                   mpatches.Patch(color='maroon', label='232(val) PL acyl'),
                   mpatches.Patch(color='tomato', label='236(leu) PL acyl'),
                   mpatches.Patch(color='sienna', label='239(leu) PL acyl'),
                   mpatches.Patch(color='salmon', label='243(leu) PL acyl'),
                   mpatches.Patch(color='navy', label='228(leu) TG acyl'),
                   mpatches.Patch(color='royalblue', label='232(val) TG acyl'),
                   mpatches.Patch(color='lightsteelblue', label='236(leu) TG acyl'),
                   mpatches.Patch(color='slategrey', label='239(leu) TG acyl'),
                   mpatches.Patch(color='dodgerblue', label='243(leu) TG acyl')]
fig.legend(handles=legend_elements, bbox_to_anchor=(0.5,-0.07), loc="lower center", ncol=5)
for i in range(6, 8):
    axs[i].set_xlabel("Frame")
plt.tight_layout()
plt.show()

# %%
fig, axs = plt.subplots(4, 2, figsize=(8, 11))
axs = axs.ravel()

for i, trajnum in enumerate(range(1, 9)):
    rol = pd.read_csv(f'rep{trajnum}/tot.csv')
    
    rol.plot(x='Frame',y='228(leu) PL acyl', color='red',ax=axs[i], legend=None)
    rol.plot(x='Frame',y='232(val) PL acyl', color='maroon',ax=axs[i],legend= None)
    rol.plot(x='Frame',y='236(leu) PL acyl', color='tomato',ax=axs[i],legend=None)
    rol.plot(x='Frame',y='239(leu) PL acyl', color='sienna',ax=axs[i],legend=None)
    rol.plot(x='Frame',y='243(leu) PL acyl', color='salmon',ax=axs[i],legend=None)

    rol.plot(x='Frame',y='228(leu) TG acyl', color='navy',ax=axs[i],legend=None)
    rol.plot(x='Frame',y='232(val) TG acyl', color='royalblue',ax=axs[i],legend=None)
    rol.plot(x='Frame',y='236(leu) TG acyl', color='lightsteelblue',ax=axs[i],legend=None)
    rol.plot(x='Frame',y='239(leu) TG acyl', color='slategrey',ax=axs[i],legend=None)
    rol.plot(x='Frame',y='243(leu) TG acyl', color='dodgerblue',ax=axs[i],legend=None)

    axs[i].set_title(f'hydrophobic contacts rep-{trajnum} pure-TG')
    if i not in [6,7]:
        axs[i].set_xlabel("")
        axs[i].set_xticks([])
    if i in [6,7]:
        axs[i].set_xlabel("time (ns)")
    if i in [0,2,4,6]:
        axs[i].set_ylabel('contacts')

legend_elements = [mpatches.Patch(color='red', label='228(leu) PL acyl'),
                   mpatches.Patch(color='maroon', label='232(val) PL acyl'),
                   mpatches.Patch(color='tomato', label='236(leu) PL acyl'),
                   mpatches.Patch(color='sienna', label='239(leu) PL acyl'),
                   mpatches.Patch(color='salmon', label='243(leu) PL acyl'),
                   mpatches.Patch(color='navy', label='228(leu) TG acyl'),
                   mpatches.Patch(color='royalblue', label='232(val) TG acyl'),
                   mpatches.Patch(color='lightsteelblue', label='236(leu) TG acyl'),
                   mpatches.Patch(color='slategrey', label='239(leu) TG acyl'),
                   mpatches.Patch(color='dodgerblue', label='243(leu) TG acyl')]
fig.legend(handles=legend_elements, bbox_to_anchor=(0.5,-0.07), loc="lower center", ncol=5,shadow=True,fancybox=True)
plt.tight_layout()
plt.savefig('hydro_contacts_new.png',bbox_inches='tight', dpi=200)
plt.show()
